# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

file_path = '/content/drive/MyDrive/MobitelData/mobi_data2_combined.csv'
df = pd.read_csv(file_path, low_memory=False)
display(df.head())
# Out:
#    Root alarm  Critical  2026-07-07 19:26:47  2026-07-07 19:27:57    29240  \
# 0  Root alarm  Critical  2026-07-07 19:26:47  2026-07-07 19:27:50  29240.0
# 1  Root alarm  Critical  2026-07-07 19:26:47  2026-07-07 19:27:57  29240.0
# 2  Root alarm  Critical  2026-07-07 19:28:29  2026-07-07 19:29:26  29240.0
# 3  Root alarm  Critical  2026-07-07 19:29:26  2026-07-07 19:30:39  29240.0
# 4  Root alarm  Critical  2026-07-07 19:29:50  2026-07-07 19:30:57  29240.0
#
#   eNodeB Function Name=BDPAS2_L_Passara_town_Ba, Local Cell ID=82, Cell Name=BDPAS2-M-L85-C1, Cell FDD TDD indication=CELL_FDD  \
# 0  eNodeB Function Name=BDPAS2_L_Passara_town_Ba,...
# 1  eNodeB Function Name=BDPAS2_L_Passara_town_Ba,...
# 2  eNodeB Function Name=BDPAS2_L_Passara_town_Ba,...
# 3  eNodeB Function Name=BDPAS2_L_Passara_town_Ba,...
# 4  eNodeB Function Name=BDPAS2_L_Passara_town_Ba,...
#
#      -  Cell Unavailable  \
# 0  NaN  Cell Unavailable
# 1  NaN  Cell Unavailable
# 2  NaN  Cell Unavailable
# 3  NaN  Cell Unavailable
# 4  NaN  Cell Unavailable
#
#   eNodeB Function Name=BDPAS2_L_Passara_town_Ba, Local Cell ID=82, Cell FDD TDD indication=FDD, NB-IoT Cell Flag=FALSE, Cell Name=BDPAS2-M-L85-C1, eNodeB ID=3537, Cell ID=83, Specific Problem=RF Power OFF  \
# 0  eNodeB Function Name=BDPAS2_L_Passara_town_Ba,...
# 1  eNodeB Function Name=BDPAS2_L_Passara_town_Ba,...
# 2  eNodeB Function Name=BDPAS2_L_Passara_town_Ba,...
# 3  eNodeB Function Name=BDPAS2_L_Passara_town_Ba,...
# 4  eNodeB Function Name=BDPAS2_L_Passara_town_Ba,...
#
#   RAT_INFO=GL, AFFECTED_RAT=L, DID=NULL, Cumulative Duration(s)=90, eNodeBId=3537  \
# 0  RAT_INFO=GL, AFFECTED_RAT=L, DID=NULL, Cumulat...
# 1  RAT_INFO=GL, AFFECTED_RAT=L, DID=NULL, Cumulat...
# 2  RAT_INFO=GL, AFFECTED_RAT=L, DID=NULL, Cumulat...
# 3  RAT_INFO=GL, AFFECTED_RAT=L, DID=NULL, Cumulat...
# 4  RAT_INFO=GL, AFFECTED_RAT=L, DID=NULL, Cumulat...
#
#    ... 2026-07-06 16:39:31 Environment system 2026-07-07 09:49:19  \
# 0  ...                 NaN                NaN                 NaN
# 1  ...                 NaN                NaN                 NaN
# 2  ...                 NaN                NaN                 NaN
# 3  ...                 NaN                NaN                 NaN
# 4  ...                 NaN                NaN                 NaN
#
#   2026-07-07 09:49:21 0 hours 0 minutes 2 seconds 2026-07-08 00:32:54  \
# 0                 NaN                         NaN                 NaN
# 1                 NaN                         NaN                 NaN
# 2                 NaN                         NaN                 NaN
# 3                 NaN                         NaN                 NaN
# 4                 NaN                         NaN                 NaN
#
#   &6161908-40663& 6161908 1139391082 2026-07-07 09:49:44
# 0             NaN     NaN        NaN                 NaN
# 1             NaN     NaN        NaN                 NaN
# 2             NaN     NaN        NaN                 NaN
# 3             NaN     NaN        NaN                 NaN
# 4             NaN     NaN        NaN                 NaN
#
# [5 rows x 205 columns]
# Warning: Total number of columns (205) exceeds max_columns (20) limiting to first (20) columns.

# %%
# Re-load the CSV file, specifying no header
df = pd.read_csv(file_path, header=None, low_memory=False)
display(df.head())
